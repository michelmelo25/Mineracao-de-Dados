# %% [markdown]
# # Atividades
#
# ## Analisando dados de ocorrências de feminicídio na cidade de São Paulo
#
# Algumas perguntas com relação ao dataset podem ser respondidas
# - Como os índices de feminicídio evoluíram em relação ao tempo e como podem evoluir nos próximos anos?
# - Quais foram os períodos com maiores taxas nos últimos anos?
# - Quais são os logradouros, tipos de locais, bairros e regiões com maiores índices?
# - Quais são os dias da semana, horários com maiores índices?
#
# Dataset disponível em: http://www.ssp.sp.gov.br/transparenciassp/Default.aspx

# %% [markdown]
# **Michel de Melo Vieira - 389959**

# %%
# Leitura dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Df20181 = pd.read_excel('../Datasets/2018_1.xlsx')

# %%
Df20182 = pd.read_excel('../Datasets/2018_2.xlsx')

# %%
Df20183 = pd.read_excel('../Datasets/2018_3.xlsx')

# %%
Df20184 = pd.read_excel('../Datasets/2018_4.xlsx')

# %%
Df20185 = pd.read_excel('../Datasets/2018_5.xlsx')

# %%
Df20186 = pd.read_excel('../Datasets/2018_6.xlsx')

# %%
Df20191 = pd.read_excel('../Datasets/DadosBO_2019_1(FEMINICÍDIO).xlsx')

# %%
Df20192 = pd.read_excel('../Datasets/DadosBO_2019_2(FEMINICÍDIO).xlsx')

# %%
Df20193 = pd.read_excel('../Datasets/DadosBO_2019_3(FEMINICÍDIO).xlsx')

# %%
Df20194 = pd.read_excel('../Datasets/DadosBO_2019_4(FEMINICÍDIO).xlsx')

# %%
Df20195 = pd.read_excel('../Datasets/DadosBO_2019_5(FEMINICÍDIO).xlsx')

# %%
Df20196 = pd.read_excel('../Datasets/DadosBO_2019_6(FEMINICÍDIO).xlsx')

# %% [markdown]
# juntando os datasets

# %%
df = pd.concat([Df20181,Df20182,Df20183,Df20184,Df20185,Df20186, Df20191, Df20192, Df20193, Df20194, Df20195, Df20196])

# %%
df.shape
# Out:
# (290, 56)

# %%
df.head()
# Out:
#    ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2018     141       141/2018  03/01/2018 17:22:43  03/01/2018 19:14:25
# 1    2018     141       141/2018  03/01/2018 17:22:43  03/01/2018 19:14:25
# 2    2018     141       141/2018  03/01/2018 17:22:43  03/01/2018 19:14:25
# 3    2018     150       150/2018  07/01/2018 02:28:38  07/01/2018 05:29:57
# 4    2018     150       150/2018  07/01/2018 02:28:38  07/01/2018 05:29:57
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0     03/01/2018          A TARDE      03/01/2018  03/01/2018 17:22:43
# 1     03/01/2018          A TARDE      03/01/2018  03/01/2018 17:22:43
# 2     03/01/2018          A TARDE      03/01/2018  03/01/2018 17:22:43
# 3     07/01/2018     DE MADRUGADA      07/01/2018  07/01/2018 02:28:38
# 4     07/01/2018     DE MADRUGADA      07/01/2018  07/01/2018 02:28:38
#
#   BO_AUTORIA  ... PLACA_VEICULO UF_VEICULO CIDADE_VEICULO  DESCR_COR_VEICULO  \
# ...

# %% [markdown]
# ## Pré-processamento
#
# Antes de analisar, caso necessário, realiza um procedimento de limpeza de dados, como remover duplicados, tratar strings, converter dados para outros formatos, criar novas colunas como dia do mês, da semana e mês.
#
# **P.S.**: *Essa pode ser a fase mais demorada de todo o desafio.*

# %%
# REMOVENDO DADOS DUPLICADOS
    #nao a dados duplicados

# TRANSFORMANDO STRINGS PARA LOWER CASE
    #tranformado

# PADRONIZANDO STRING

# TRANSFORMANDO DADOS TEMPORAIS NO TIPO APROPRIADO
    #tranformado

# %% [markdown]
# Informacoes a respeito dos dados

# %%
df.describe()
# Out:
#             ANO_BO       NUM_BO       NUMERO   LATITUDE  LONGITUDE  \
# count   290.000000   290.000000   288.000000  85.000000  85.000000
# mean   2018.586207  1390.965517   131.861111 -22.756730 -47.248525
# std       0.493364  1386.430611   452.007579   1.009081   1.086322
# min    2018.000000    12.000000     0.000000 -23.683681 -51.089386
# 25%    2018.000000   320.250000     0.000000 -23.495607 -47.466455
# 50%    2019.000000   974.000000     0.000000 -23.110795 -46.893262
# 75%    2019.000000  1958.000000     0.250000 -22.474077 -46.597479
# max    2019.000000  9959.000000  2605.000000 -20.316348 -45.056774
#
#                  RG       IDADE  PARENTESCO  ANO_FABRICACAO   ANO_MODELO  \
# count  2.460000e+02  251.000000         0.0      290.000000   290.000000
# mean   3.703537e+07   36.936255         NaN        6.962069     6.962069
# std    1.455231e+07   13.422515         NaN      118.559762   118.559762
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290 entries, 0 to 17
# Data columns (total 56 columns):
# ANO_BO                      290 non-null int64
# NUM_BO                      290 non-null int64
# NUMERO_BOLETIM              290 non-null object
# BO_INICIADO                 290 non-null object
# BO_EMITIDO                  290 non-null object
# DATAOCORRENCIA              290 non-null object
# PERIDOOCORRENCIA            290 non-null object
# DATACOMUNICACAO             290 non-null object
# DATAELABORACAO              290 non-null object
# BO_AUTORIA                  290 non-null object
# FLAGRANTE                   290 non-null object
# NUMERO_BOLETIM_PRINCIPAL    35 non-null object
# LOGRADOURO                  85 non-null object
# NUMERO                      288 non-null float64
# BAIRRO                      288 non-null object
# CIDADE                      288 non-null object
# UF                          288 non-null object
# ...

# %%
df.corr()
# Out:
#                   ANO_BO    NUM_BO    NUMERO  LATITUDE  LONGITUDE        RG  \
# ANO_BO          1.000000  0.048426 -0.131544 -0.015073  -0.133050 -0.037746
# NUM_BO          0.048426  1.000000 -0.093613 -0.329308   0.167376 -0.094594
# NUMERO         -0.131544 -0.093613  1.000000  0.264332  -0.010340  0.084392
# LATITUDE       -0.015073 -0.329308  0.264332  1.000000  -0.578695  0.033334
# LONGITUDE      -0.133050  0.167376 -0.010340 -0.578695   1.000000 -0.055231
# RG             -0.037746 -0.094594  0.084392  0.033334  -0.055231  1.000000
# IDADE           0.030411  0.005349  0.002889  0.071775  -0.023929 -0.767535
# PARENTESCO           NaN       NaN       NaN       NaN        NaN       NaN
# ANO_FABRICACAO  0.049422  0.022825  0.001065 -0.019112   0.013974       NaN
# ANO_MODELO      0.049422  0.022825  0.001065 -0.019112   0.013974       NaN
# QUANT_CELULAR        NaN       NaN       NaN       NaN        NaN       NaN
# ...

# %% [markdown]
# Tranformando strings em low case

# %%
for col in df:
    if(df[col].dtype == 'object'):
        df[col] = df[col].str.lower()

# %% [markdown]
# Alteranro tipo dos dados referentes a data para datetime

# %%
df['BO_INICIADO'] = pd.to_datetime(df['BO_INICIADO']) 
df['BO_EMITIDO'] = pd.to_datetime(df['BO_EMITIDO'])
df['DATAOCORRENCIA'] = pd.to_datetime(df['DATAOCORRENCIA'])
df['DATACOMUNICACAO'] = pd.to_datetime(df['DATACOMUNICACAO'])
df['DATAELABORACAO'] = pd.to_datetime(df['DATAELABORACAO'])
df['DATANASCIMENTO'] = pd.to_datetime(df['DATANASCIMENTO'])

# %%
df
# Out:
#     ANO_BO  NUM_BO NUMERO_BOLETIM         BO_INICIADO          BO_EMITIDO  \
# 0     2018     141       141/2018 2018-03-01 17:22:43 2018-03-01 19:14:25
# 1     2018     141       141/2018 2018-03-01 17:22:43 2018-03-01 19:14:25
# 2     2018     141       141/2018 2018-03-01 17:22:43 2018-03-01 19:14:25
# 3     2018     150       150/2018 2018-07-01 02:28:38 2018-07-01 05:29:57
# 4     2018     150       150/2018 2018-07-01 02:28:38 2018-07-01 05:29:57
# 5     2018     150       150/2018 2018-07-01 02:28:38 2018-07-01 05:29:57
# 6     2018     321       321/2018 2018-01-15 22:50:00 2018-01-15 23:42:28
# 7     2018     117       117/2018 2018-01-16 09:48:45 2018-01-16 14:14:00
# 8     2018     292       292/2018 2018-01-28 13:39:22 2018-01-28 19:12:43
# 0     2018     565       565/2018 2018-03-02 12:41:42 2018-03-02 17:38:56
# 1     2018     718       718/2018 2018-05-02 04:59:34 2018-05-02 06:23:30
# 2     2018     718       718/2018 2018-05-02 04:59:34 2018-05-02 06:23:30
# ...

# %%
dfnew = df.drop_duplicates(subset='NUM_BO', keep='first')

# %% [markdown]
# ## Análise Exploratória
#
# Agora é a hora de descobrir relações e algumas *hidden informations* do dataset.

# %% [markdown]
# ### CIADE

# %%
dfnew[dfnew['ANO_BO'] == 2018]['CIDADE'].value_counts().plot(kind='bar',figsize=(15,6));

# %%
dfnew[dfnew['ANO_BO'] == 2019]['CIDADE'].value_counts().plot(kind='bar',figsize=(15,6));

# %% [markdown]
# ### ANO

# %%
dfnew.groupby('ANO_BO').size()
# Out:
# ANO_BO
# 2018    57
# 2019    80
# dtype: int64

# %%
dfnew.groupby('ANO_BO').size().plot(kind='bar',figsize=(15,6));

# %% [markdown]
# ### IDADE

# %%
dfnew[dfnew['ANO_BO'] == 2018].groupby('IDADE').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,4));

# %%
dfnew[dfnew['ANO_BO'] == 2019].groupby('IDADE').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,4));

# %% [markdown]
# ### RAÇA

# %%
dfnew[dfnew['ANO_BO'] == 2018].groupby('CORCUTIS').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %%
dfnew[dfnew['ANO_BO'] == 2019].groupby('CORCUTIS').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %% [markdown]
# ### GRADUAÇÃO

# %%
dfnew[dfnew['ANO_BO'] == 2018].groupby('GRAUINSTRUCAO').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %%
dfnew[dfnew['ANO_BO'] == 2019].groupby('GRAUINSTRUCAO').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %% [markdown]
# ### PERIODO

# %%
dfnew[dfnew['ANO_BO'] == 2018].groupby('PERIDOOCORRENCIA').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %%
dfnew[dfnew['ANO_BO'] == 2019].groupby('PERIDOOCORRENCIA').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %%
dfnew[dfnew['ANO_BO'] == 2018].groupby('BAIRRO').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %%
dfnew[dfnew['ANO_BO'] == 2019].groupby('BAIRRO').size().sort_values(ascending=False).plot(kind='bar',figsize=(15,6));

# %%
plt.subplot(2,1,1);
dfnew[dfnew['ANO_BO'] == 2018].groupby('BAIRRO').size().sort_values(ascending=False)[0:5].plot(kind='bar',figsize=(10,10));
plt.subplot(2,1,2);
dfnew[dfnew['ANO_BO'] == 2019].groupby('BAIRRO').size().sort_values(ascending=False)[0:5].plot(kind='bar');
plt.show();

# %% [markdown]
# # RELATORIO
#
# #### Analise comparativa do periodo de Janeiro - Junho de 2018 com Janeiro - Junho 2019
#
# <p>
# Neste pariodo ouve um crescimento de 40,35% nos crimes de feminicidio no estado de São Paulo, podemos observar que entre as 5 primeiras cidades ouve uma leve alteração no numero de BOs registrados nas cidades com uma pequena caida nas cidades de Guarulos, Idaiatuba e um um leve almento nas ciades de São Paulo, Campinas, Santo André, Maua, também tem se demontrado uma pequena queda em relação a idade das vitimas onde mulhes mais jovem então sendo assacinadas.
# </p>
# <p>
# Em relação ao mesmo periodo de 2018, 2019 manteve a mesma proporção a raça das vitimas com a maioria tento o segundo grau incompleto, a noite e madrugada paulista tem se tornado mais violenta no ano de 2019 consentando-se em bairros da capital como Centro, Tremembe, Capaão Redondo e zona rural com a maioria das vitimas.
# </p>
